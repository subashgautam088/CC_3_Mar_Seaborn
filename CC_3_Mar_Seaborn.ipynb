# %%
import seaborn as sns

# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.
# --> Five plots that we can plot using the Seaborn library are:
# 1) Scatter Plots
# 2) Line Plots
# 3) Bar Plots
# 4) Histogram
# 5) Heatmap

# %%
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
import seaborn as sns
fmri = sns.load_dataset("fmri")
sns.lineplot(x =fmri.timepoint, y =fmri.signal,data = fmri , hue = "event", style = "region",markers = True,dashes = False)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.
import seaborn as sns 
import matplotlib.pyplot as plt
titanic = sns.load_dataset("titanic")
# Box plot for 'age' by 'pclass'
sns.boxplot(data = titanic, x = "pclass", y = "age")
plt.title("Ageb Distribution by Passenger Class")
# Out:
# Text(0.5, 1.0, 'Ageb Distribution by Passenger Class')

# %%
# Box plot for 'fare' by 'pclass'
sns.boxplot(data = titanic, x = 'pclass', y = 'fare')
plt.title("Fare Distribution by Passenger Class")
# Out:
# Text(0.5, 1.0, 'Fare Distribution by Passenger Class')

# %%
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.
import seaborn as sns
import matplotlib.pyplot as plt
diamonds = sns.load_dataset("diamonds")
sns.histplot(data = diamonds,x = 'price',hue = 'cut', multiple = 'stack',kde=True)
plt.title("Histogram Graph by Price")
# Out:
# Text(0.5, 1.0, 'Histogram Graph by Price')

# %%
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.
import seaborn as sns
import matplotlib.pyplot as plt
iris = sns.load_dataset("iris")
sns.pairplot(data = iris, hue = "species")
plt.title("Pair Plot of Iris Data Set ")
# Out:
# Text(0.5, 1.0, 'Pair Plot of Iris Data Set ')

# %%
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.
import seaborn as sns
import 
flights = sns.load_dataset("flights")
flights_pivot = flights.pivot("month","year","passengers")
sns.heatmap(flights_pivot, annot=True,fmt="d")
# Out:
# /tmp/ipykernel_110/1340252531.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_pivot = flights.pivot("month","year","passengers")
# <AxesSubplot: xlabel='year', ylabel='month'>
